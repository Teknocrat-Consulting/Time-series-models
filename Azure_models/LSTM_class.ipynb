# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Use TensorFlow's Keras, not standalone Keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Class module

# %%
class LSTM_predictions():
    def __init__(self,df,pred_column,date_col = "timestamp",epoch=10):
        self.df = df
        self.epoch = epoch
        print("Columns: ",self.df.columns)
        print("Data shape: ",self.df.shape)
        self.df[date_col] = pd.to_datetime(self.df[date_col], errors='coerce')
        self.df = self.df[[date_col,pred_column]]
        print("*"*60)

        data = df.filter([pred_column])
        dataset = data.values

        # Get the number of rows to train the model on
        training_data_len = int(np.ceil( len(dataset) * .80 ))
        train_data = df.iloc[0:int(training_data_len), :]
        test_data = df.iloc[training_data_len - 60: , :]   

        print("Train size :",train_data.shape)
        print("Test size :",test_data.shape)

        self.train_data = train_data[[pred_column, date_col]].to_numpy()
        self.test_data = test_data[[pred_column, date_col]].to_numpy()

        print("*"*60)

    def plot(self,df,pred_column):
        self.df[pred_column].plot(title=f'{pred_column} over Time')

    def create_sequences_lstm(self,data, seq_length=12):
        xs = []
        ys = []
        indices = []
        for i in range(len(data)-seq_length-1):
            x = data[i:(i+seq_length), 0:1]  # Select only the feature columns
            y = data[i+seq_length, 0]  # Select the target value
            xs.append(x)
            ys.append(y)
            indices.append(data[i+seq_length, 1])  # Capture the timestamp for plotting
        return np.array(xs), np.array(ys), np.array(indices)
    
    def create_model(self,X_train):
        model = Sequential()
        model.add(LSTM(128, return_sequences=True, input_shape= (X_train.shape[1], 1)))
        model.add(LSTM(64, return_sequences=False))
        model.add(Dense(25))
        model.add(Dense(1))
        # Compile the model
        model.compile(optimizer='adam', loss='mean_squared_error')
        return model

    
    def run(self):

        train_data = self.train_data
        test_data = self.test_data

        scaler = MinMaxScaler(feature_range=(0, 1))
        train_data[:, 0] = scaler.fit_transform(train_data[:, 0].reshape(-1, 1)).flatten()
        test_data[:, 0] = scaler.transform(test_data[:, 0].reshape(-1, 1)).flatten()    

        X_train, y_train,indices_train  = self.create_sequences_lstm(train_data)
        X_test, y_test,indices_test = self.create_sequences_lstm(test_data)

        y_train = np.array([np.array([item]) for item in y_train])
        y_test = np.array([np.array([item]) for item in y_test])

        train_indices = pd.to_datetime(indices_train)
        test_indices = pd.to_datetime(indices_test)

        # To check the data shape for LSTM
        print("Train and Test Size after preprocessing: ")

        print("X_train shape: ",X_train.shape)
        print("y_train shape: ",y_train.shape)
        print("X_test shape: ",X_test.shape)
        print("y_test shape: ",y_test.shape)
        print("*"*60)

        model = self.create_model(X_train)

        X_train = X_train.astype('float32')
        X_test = X_test.astype('float32')
        y_train = y_train.astype('float32')
        y_test = y_test.astype('float32')

        assert not np.any(np.isnan(X_train))
        assert not np.any(np.isnan(X_test))
        assert not np.any(np.isnan(y_train))
        assert not np.any(np.isnan(y_test))

        #print(X_train[0],y_train[0])

        history = model.fit(X_train, y_train, batch_size=32, epochs=self.epoch,verbose=1,validation_data=(X_test,y_test))
        print("Training details :",history)
        print("*"*60)

        plt.figure(figsize=(10, 6))
        plt.plot(history.history['loss'], label='Train Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title('Model Loss Progress During Training')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend()
        plt.show()

        # Predicting and inverse transform to original scale
        y_train_pred = model.predict(X_train)
        y_test_pred = model.predict(X_test)
        y_train_pred = scaler.inverse_transform(y_train_pred)
        y_test_pred = scaler.inverse_transform(y_test_pred)
        y_train = scaler.inverse_transform(y_train.reshape(-1,1))
        y_test = scaler.inverse_transform(y_test.reshape(-1,1))

        # Calculate performance metrics
        train_mse = mean_squared_error(y_train, y_train_pred)
        train_rmse = np.sqrt(train_mse)
        train_mae = mean_absolute_error(y_train, y_train_pred)
        train_mape = np.mean(np.abs((y_train - y_train_pred) / y_train)) * 100

        test_mse = mean_squared_error(y_test, y_test_pred)
        test_rmse = np.sqrt(test_mse)
        test_mae = mean_absolute_error(y_test, y_test_pred)
        test_mape = np.mean(np.abs((y_test - y_test_pred) / y_test)) * 100

        print('Train MSE:', train_mse)
        print('Train RMSE:', train_rmse)
        print('Train MAE:', train_mae)
        print('Train MAPE:', train_mape)
        print("*"*60)

        print('Test MSE:', test_mse)
        print('Test RMSE:', test_rmse)
        print('Test MAE:', test_mae)
        print('Test MAPE:', test_mape)

        train_indices = pd.to_datetime(train_indices)
        test_indices = pd.to_datetime(test_indices)

        # Plot training data
        plt.figure(figsize=(15,7))
        plt.plot(train_indices, y_train.flatten(), label='Actual Train', color='blue')
        plt.plot(train_indices, y_train_pred.flatten(), label='Predicted Train', color='orange')
        plt.title('Train Prediction')
        plt.xlabel('Time')
        plt.ylabel('Average CPU Usage')
        plt.legend()
        plt.grid(True)
        plt.show()

        # Plot testing data
        plt.figure(figsize=(15,7))
        plt.plot(test_indices, y_test.flatten(), label='Actual Test', color='blue')
        plt.plot(test_indices, y_test_pred.flatten(), label='Predicted Test', color='orange')
        plt.title('Test Prediction')
        plt.xlabel('Time')
        plt.ylabel('Average CPU Usage')
        plt.legend()
        plt.grid(True)
        plt.show()

# %% [markdown]
# # Performance on Azure Datset

# %%
df_azure = pd.read_csv("azure.csv")
azure = LSTM_predictions(df_azure,"avg cpu",epoch=100)
azure.plot(df_azure,"avg cpu")
azure.run()
# Out:
# Columns:  Index(['timestamp', 'min cpu', 'max cpu', 'avg cpu'], dtype='object')
# Data shape:  (8640, 4)
# ************************************************************
# Train size : (6912, 4)
# Test size : (1788, 4)
# ************************************************************
# Train and Test Size after preprocessing:
# X_train shape:  (6899, 12, 1)
# y_train shape:  (6899, 1)
# X_test shape:  (1775, 12, 1)
# y_test shape:  (1775, 1)
# ************************************************************
# Epoch 1/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0069 - val_loss: 9.3448e-04
# Epoch 2/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 9.3583e-04 - val_loss: 8.7903e-04
# Epoch 3/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 8.1193e-04 - val_loss: 6.7904e-04
# Epoch 4/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 7.2021e-04 - val_loss: 6.2468e-04
# Epoch 5/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 6.2020e-04 - val_loss: 5.2472e-04
# Epoch 6/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 5.8648e-04 - val_loss: 4.9576e-04
# Epoch 7/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 5.2790e-04 - val_loss: 4.9036e-04
# Epoch 8/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 5.1379e-04 - val_loss: 5.2987e-04
# Epoch 9/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4.3081e-04 - val_loss: 4.4250e-04
# Epoch 10/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.4623e-04 - val_loss: 4.3647e-04
# Epoch 11/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4.6954e-04 - val_loss: 4.7510e-04
# Epoch 12/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.8867e-04 - val_loss: 4.6226e-04
# Epoch 13/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4.4991e-04 - val_loss: 4.6980e-04
# Epoch 14/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4.2263e-04 - val_loss: 4.8244e-04
# Epoch 15/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.0440e-04 - val_loss: 4.8153e-04
# Epoch 16/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.4809e-04 - val_loss: 4.4310e-04
# Epoch 17/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.1925e-04 - val_loss: 6.4427e-04
# Epoch 18/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.3997e-04 - val_loss: 6.8739e-04
# Epoch 19/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.7070e-04 - val_loss: 4.3856e-04
# Epoch 20/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.7308e-04 - val_loss: 4.8812e-04
# Epoch 21/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.5716e-04 - val_loss: 5.1248e-04
# Epoch 22/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4.5438e-04 - val_loss: 4.7503e-04
# Epoch 23/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.2643e-04 - val_loss: 4.4500e-04
# Epoch 24/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.3348e-04 - val_loss: 4.7166e-04
# Epoch 25/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4.5147e-04 - val_loss: 4.8063e-04
# Epoch 26/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.6368e-04 - val_loss: 4.5898e-04
# Epoch 27/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4.5341e-04 - val_loss: 4.3922e-04
# Epoch 28/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.4060e-04 - val_loss: 4.4968e-04
# Epoch 29/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.2826e-04 - val_loss: 4.4661e-04
# Epoch 30/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.1830e-04 - val_loss: 6.0947e-04
# Epoch 31/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.5484e-04 - val_loss: 4.8429e-04
# Epoch 32/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 4.3772e-04 - val_loss: 4.6313e-04
# Epoch 33/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.2616e-04 - val_loss: 7.0042e-04
# Epoch 34/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.3321e-04 - val_loss: 4.4853e-04
# Epoch 35/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.7007e-04 - val_loss: 4.4361e-04
# Epoch 36/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 4.6494e-04 - val_loss: 4.7915e-04
# Epoch 37/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.4620e-04 - val_loss: 4.6356e-04
# Epoch 38/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.5967e-04 - val_loss: 4.7790e-04
# Epoch 39/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.4400e-04 - val_loss: 5.8874e-04
# Epoch 40/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 4.5341e-04 - val_loss: 4.6277e-04
# Epoch 41/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.1190e-04 - val_loss: 4.5107e-04
# Epoch 42/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4.1889e-04 - val_loss: 5.1741e-04
# Epoch 43/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.5127e-04 - val_loss: 5.5647e-04
# Epoch 44/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.5178e-04 - val_loss: 4.7906e-04
# Epoch 45/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.0357e-04 - val_loss: 0.0010
# Epoch 46/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.4706e-04 - val_loss: 4.7831e-04
# Epoch 47/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4.4834e-04 - val_loss: 4.7251e-04
# Epoch 48/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.5079e-04 - val_loss: 4.3326e-04
# Epoch 49/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.2763e-04 - val_loss: 4.9211e-04
# Epoch 50/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 4.1183e-04 - val_loss: 4.4278e-04
# Epoch 51/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.6320e-04 - val_loss: 5.2862e-04
# Epoch 52/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 4.4536e-04 - val_loss: 4.2941e-04
# Epoch 53/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.3651e-04 - val_loss: 4.4696e-04
# Epoch 54/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.3066e-04 - val_loss: 4.7139e-04
# Epoch 55/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.5883e-04 - val_loss: 4.5119e-04
# Epoch 56/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.0837e-04 - val_loss: 4.5219e-04
# Epoch 57/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.9682e-04 - val_loss: 4.5631e-04
# Epoch 58/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.4581e-04 - val_loss: 4.2584e-04
# Epoch 59/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.3625e-04 - val_loss: 3.8117e-04
# Epoch 60/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.5650e-04 - val_loss: 4.6801e-04
# Epoch 61/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.7242e-04 - val_loss: 3.7110e-04
# Epoch 62/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.7127e-04 - val_loss: 3.8426e-04
# Epoch 63/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 3.7351e-04 - val_loss: 3.7663e-04
# Epoch 64/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.5512e-04 - val_loss: 3.7661e-04
# Epoch 65/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.3572e-04 - val_loss: 5.4378e-04
# Epoch 66/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.5619e-04 - val_loss: 3.8558e-04
# Epoch 67/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4.0304e-04 - val_loss: 3.7035e-04
# Epoch 68/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.5026e-04 - val_loss: 4.1310e-04
# Epoch 69/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.8141e-04 - val_loss: 3.8678e-04
# Epoch 70/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.5372e-04 - val_loss: 3.9669e-04
# Epoch 71/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.3635e-04 - val_loss: 3.9336e-04
# Epoch 72/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.7596e-04 - val_loss: 3.4173e-04
# Epoch 73/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 3.3300e-04 - val_loss: 3.5282e-04
# Epoch 74/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 3.1520e-04 - val_loss: 3.4914e-04
# Epoch 75/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.5815e-04 - val_loss: 3.6191e-04
# Epoch 76/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.1638e-04 - val_loss: 4.2471e-04
# Epoch 77/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.3892e-04 - val_loss: 4.0657e-04
# Epoch 78/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.6028e-04 - val_loss: 3.4918e-04
# Epoch 79/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.1110e-04 - val_loss: 4.4381e-04
# Epoch 80/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.5822e-04 - val_loss: 3.7976e-04
# Epoch 81/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.4761e-04 - val_loss: 3.3399e-04
# Epoch 82/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 3.2549e-04 - val_loss: 3.4213e-04
# Epoch 83/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 3.1982e-04 - val_loss: 3.3489e-04
# Epoch 84/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.0620e-04 - val_loss: 3.3043e-04
# Epoch 85/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.3887e-04 - val_loss: 3.8824e-04
# Epoch 86/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 3.5003e-04 - val_loss: 3.6494e-04
# Epoch 87/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.3548e-04 - val_loss: 4.0705e-04
# Epoch 88/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.3839e-04 - val_loss: 4.2908e-04
# Epoch 89/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 2.9298e-04 - val_loss: 3.5496e-04
# Epoch 90/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.4396e-04 - val_loss: 3.4179e-04
# Epoch 91/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.0738e-04 - val_loss: 4.4171e-04
# Epoch 92/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.7820e-04 - val_loss: 4.0220e-04
# Epoch 93/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.2442e-04 - val_loss: 3.7459e-04
# Epoch 94/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.3196e-04 - val_loss: 3.5994e-04
# Epoch 95/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.4839e-04 - val_loss: 3.5665e-04
# Epoch 96/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.3403e-04 - val_loss: 4.9438e-04
# Epoch 97/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.2117e-04 - val_loss: 4.0726e-04
# Epoch 98/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.2963e-04 - val_loss: 3.4014e-04
# Epoch 99/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.2226e-04 - val_loss: 3.7046e-04
# Epoch 100/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.1479e-04 - val_loss: 3.4250e-04
# Training details : <keras.src.callbacks.history.History object at 0x00000208D3E03FD0>
# ************************************************************
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 216210850.0
# Train RMSE: 14704.11
# Train MAE: 10711.521
# Train MAPE: 0.8883259259164333
# ************************************************************
# Test MSE: 243463360.0
# Test RMSE: 15603.3125
# Test MAE: 11328.405
# Test MAPE: 0.8793969638645649

# %% [markdown]
# # Performance on IEEE data while predicting Energy Consumption

# %%
df_workstation = pd.read_csv("workstation_data.csv")

# %%
ieee = LSTM_predictions(df_workstation,"energy",epoch=20)
ieee.plot(df_workstation,"energy")
ieee.run()
# Out:
# Columns:  Index(['timestamp', 'voltage', 'current', 'power', 'frequency', 'energy', 'fp',
#        'ESP32_temp', 'WORKSTATION_CPU', 'WORKSTATION_CPU_POWER',
#        'WORKSTATION_CPU_TEMP', 'WORKSTATION_GPU', 'WORKSTATION_GPU_POWER',
#        'WORKSTATION_GPU_TEMP', 'WORKSTATION_RAM', 'WORKSTATION_RAM_POWER'],
#       dtype='object')
# Data shape:  (22857, 16)
# ************************************************************
# Train size : (18286, 16)
# Test size : (4631, 16)
# ************************************************************
# Train and Test Size after preprocessing:
# X_train shape:  (18273, 12, 1)
# y_train shape:  (18273, 1)
# X_test shape:  (4618, 12, 1)
# y_test shape:  (4618, 1)
# ************************************************************
# Epoch 1/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.0159 - val_loss: 7.8418e-05
# Epoch 2/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 2.6079e-06 - val_loss: 6.1475e-05
# Epoch 3/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 2.2480e-06 - val_loss: 2.3256e-05
# Epoch 4/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 1.9615e-06 - val_loss: 2.8576e-05
# Epoch 5/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 3.0444e-06 - val_loss: 6.5795e-06
# Epoch 6/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 4.0347e-06 - val_loss: 5.6792e-06
# Epoch 7/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 3.3935e-05 - val_loss: 1.2451e-04
# Epoch 8/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 1.3497e-05 - val_loss: 2.6524e-04
# Epoch 9/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 1.6746e-05 - val_loss: 1.9098e-05
# Epoch 10/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 4.3960e-06 - val_loss: 2.1708e-06
# Epoch 11/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 4.7509e-06 - val_loss: 7.4451e-05
# Epoch 12/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 1.3654e-05 - val_loss: 1.2818e-04
# Epoch 13/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 6.9308e-06 - val_loss: 3.9204e-06
# Epoch 14/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 8.6233e-06 - val_loss: 8.2540e-06
# Epoch 15/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 1.8108e-05 - val_loss: 1.3041e-05
# Epoch 16/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 3.3057e-06 - val_loss: 1.9250e-05
# Epoch 17/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 6.8275e-05 - val_loss: 1.2571e-05
# Epoch 18/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 8.9717e-07 - val_loss: 4.8546e-06
# Epoch 19/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 8.0080e-07 - val_loss: 3.6823e-06
# Epoch 20/20
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 1.7414e-06 - val_loss: 5.6041e-06
# Training details : <keras.src.callbacks.history.History object at 0x00000208DDE5A290>
# ************************************************************
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Train MSE: 0.007841212
# Train RMSE: 0.08855062
# Train MAE: 0.034207996
# Train MAPE: 0.10404278291389346
# ************************************************************
# Test MSE: 0.10723414
# Test RMSE: 0.32746625
# Test MAE: 0.29524845
# Test MAPE: 0.19025381188839674

# %% [markdown]
# # Performance on Turing Dataset

# %%
df_turing = pd.read_csv("turing_clean.csv")
df_turing["timestamp"] = df_turing['day'] + " " + df_turing['hour']

# %%
turing = LSTM_predictions(df_turing,"energy_consumption",epoch=100)
turing.plot(df_turing,"energy_consumption")
turing.run()
# Out:
# Columns:  Index(['Unnamed: 0', 'cpu_model_name', 'nb_cpu_cores', 'RAM_size', 'day',
#        'hour', 'cpu_freq_limit percent', 'current_cpu_frequency_limits',
#        'cpu_usage_percent', 'ram_usage_percent', 'energy_consumption',
#        'timestamp'],
#       dtype='object')
# Data shape:  (410, 12)
# ************************************************************
# Train size : (328, 12)
# Test size : (142, 12)
# ************************************************************
# Train and Test Size after preprocessing:
# X_train shape:  (315, 12, 1)
# y_train shape:  (315, 1)
# X_test shape:  (129, 12, 1)
# y_test shape:  (129, 1)
# ************************************************************
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.2196 - val_loss: 0.0319
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0265 - val_loss: 0.0363
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0233 - val_loss: 0.0195
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0184 - val_loss: 0.0171
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0205 - val_loss: 0.0181
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0175 - val_loss: 0.0174
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0155 - val_loss: 0.0170
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0134 - val_loss: 0.0179
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0144 - val_loss: 0.0169
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0163 - val_loss: 0.0177
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0181 - val_loss: 0.0170
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0192 - val_loss: 0.0179
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0153 - val_loss: 0.0177
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0148 - val_loss: 0.0173
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0180 - val_loss: 0.0201
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0161 - val_loss: 0.0179
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0141 - val_loss: 0.0186
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0162 - val_loss: 0.0179
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0139 - val_loss: 0.0235
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0150 - val_loss: 0.0187
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0145 - val_loss: 0.0170
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0148 - val_loss: 0.0174
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0185 - val_loss: 0.0171
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0163 - val_loss: 0.0169
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0137 - val_loss: 0.0172
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0160 - val_loss: 0.0190
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0136 - val_loss: 0.0169
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0123 - val_loss: 0.0196
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0144 - val_loss: 0.0171
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0162 - val_loss: 0.0182
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0148 - val_loss: 0.0170
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0147 - val_loss: 0.0177
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0166 - val_loss: 0.0179
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0192 - val_loss: 0.0182
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0143 - val_loss: 0.0169
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0159 - val_loss: 0.0169
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0175 - val_loss: 0.0169
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0209 - val_loss: 0.0201
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0151 - val_loss: 0.0171
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0141 - val_loss: 0.0191
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0152 - val_loss: 0.0178
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0164 - val_loss: 0.0179
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0191 - val_loss: 0.0268
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0161 - val_loss: 0.0181
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0192 - val_loss: 0.0170
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0191 - val_loss: 0.0190
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0159 - val_loss: 0.0169
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0209 - val_loss: 0.0171
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0138 - val_loss: 0.0191
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0165 - val_loss: 0.0228
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0229 - val_loss: 0.0193
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0219 - val_loss: 0.0170
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0170 - val_loss: 0.0173
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0178 - val_loss: 0.0170
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0135 - val_loss: 0.0191
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0136 - val_loss: 0.0169
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0129 - val_loss: 0.0174
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0141 - val_loss: 0.0170
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0139 - val_loss: 0.0172
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0152 - val_loss: 0.0178
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0165 - val_loss: 0.0170
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0152 - val_loss: 0.0182
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0131 - val_loss: 0.0181
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0173 - val_loss: 0.0173
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0174 - val_loss: 0.0186
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0180 - val_loss: 0.0170
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0156 - val_loss: 0.0171
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0127 - val_loss: 0.0196
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0153 - val_loss: 0.0178
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0128 - val_loss: 0.0177
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0145 - val_loss: 0.0172
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0152 - val_loss: 0.0173
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0133 - val_loss: 0.0171
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0138 - val_loss: 0.0183
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0132 - val_loss: 0.0173
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0182 - val_loss: 0.0172
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0143 - val_loss: 0.0172
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0120 - val_loss: 0.0180
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0171 - val_loss: 0.0243
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0157 - val_loss: 0.0176
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0153 - val_loss: 0.0291
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0192 - val_loss: 0.0172
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0166 - val_loss: 0.0191
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0150 - val_loss: 0.0177
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0137 - val_loss: 0.0187
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0144 - val_loss: 0.0170
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0164 - val_loss: 0.0186
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0150 - val_loss: 0.0183
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0174 - val_loss: 0.0180
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0142 - val_loss: 0.0180
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0156 - val_loss: 0.0175
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0147 - val_loss: 0.0170
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0153 - val_loss: 0.0170
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0160 - val_loss: 0.0177
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0154 - val_loss: 0.0188
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0155 - val_loss: 0.0173
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0142 - val_loss: 0.0181
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0221 - val_loss: 0.0190
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0153 - val_loss: 0.0173
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0145 - val_loss: 0.0231
# Training details : <keras.src.callbacks.history.History object at 0x00000208DFA6F1D0>
# ************************************************************
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Train MSE: 2.1103063
# Train RMSE: 1.4526893
# Train MAE: 0.9569705
# Train MAPE: 11.007215827703476
# ************************************************************
# Test MSE: 2.7116377
# Test RMSE: 1.6467052
# Test MAE: 1.4235736
# Test MAPE: 10.856763273477554
